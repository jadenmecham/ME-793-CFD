# %% [markdown]
# # Discrete Laplace/Poisson Equation

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.sparse import lil_matrix

def build_poisson_matrix(N):
    A = lil_matrix((N*N, N*N))
    for i in range(N):
        for j in range(N):
            idx = i * N + j
            A[idx, idx] = -4
            if i > 0:
                A[idx, (i-1)*N + j] = 1
            if i < N-1:
                A[idx, (i+1)*N + j] = 1
            if j > 0:
                A[idx, i*N + (j-1)] = 1
            if j < N-1:
                A[idx, i*N + (j+1)] = 1
    return A.tocsr()
def solve_poisson(N, b):
    A = build_poisson_matrix(N)
    x = np.linalg.solve(A.toarray(), b.flatten())
    return x.reshape((N, N))
N = 25
b = np.zeros((N, N))
b[10, 10] = 1  # Point source at the center
solution = solve_poisson(N, b)
plt.imshow(solution, cmap='viridis')
plt.colorbar()
plt.title('Poisson Equation Solution')
plt.show()

# %%
# build and solve poisson equation in matrix form Ax = b

L = 10
N  = 81
h = L / (N - 1)
x = np.linspace(0, L, N)
f_exact = np.cos(np.pi * x / L)
u = -(np.pi**2 / L**2) * f_exact

# boundary cond values
q0 = 0
gL = -1

e = np.ones(N)
laplacian = (np.diag(-2*e) + np.diag(e[:-1], 1) + np.diag(e[:-1], -1)) / h**2

b = f_exact.copy()

# impose neumann boundary condition at x=0
laplacian[0,:] = 0
laplacian[0, 0:2] = np.array([-3, 4, -1,])

# impose dirichlet boundary condition at x=L
laplacian[-1,:] = 0
laplacian[-1,-1] = 1

laplacian = laplacian / h**2

u_numeric = np.linalg.solve(laplacian, b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/jaden/repos/ME-793-CFD/in_class_demos/2026-02-13_in-class.ipynb Cell 3 line 2
#      <a href='vscode-notebook-cell:/home/jaden/repos/ME-793-CFD/in_class_demos/2026-02-13_in-class.ipynb#W2sZmlsZQ%3D%3D?line=18'>19</a> # impose neumann boundary condition at x=0
#      <a href='vscode-notebook-cell:/home/jaden/repos/ME-793-CFD/in_class_demos/2026-02-13_in-class.ipynb#W2sZmlsZQ%3D%3D?line=19'>20</a> laplacian[0,:] = 0
# ---> <a href='vscode-notebook-cell:/home/jaden/repos/ME-793-CFD/in_class_demos/2026-02-13_in-class.ipynb#W2sZmlsZQ%3D%3D?line=20'>21</a> laplacian[0, 0:2] = np.array([-3, 4, -1,])
#      <a href='vscode-notebook-cell:/home/jaden/repos/ME-793-CFD/in_class_demos/2026-02-13_in-class.ipynb#W2sZmlsZQ%3D%3D?line=22'>23</a> # impose dirichlet boundary condition at x=L
#      <a href='vscode-notebook-cell:/home/jaden/repos/ME-793-CFD/in_class_demos/2026-02-13_in-class.ipynb#W2sZmlsZQ%3D%3D?line=23'>24</a> laplacian[-1,:] = 0
#
# ValueError: could not broadcast input array from shape (3,) into shape (2,)

# %%
plt.plot(x, f_exact, label='Exact Solution', linestyle='dashed', color='black')
plt.plot(x, f_numeric, label='Numerical Solution', color='red')
